# %% [markdown]
# # Dataset description
# ## ISE growth
#
# **Source**: DANE
#
# **Download**: [link](https://www.dane.gov.co/index.php/estadisticas-por-tema/cuentas-nacionales/indicador-de-seguimiento-a-la-economia-ise)
#
# # Code
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
path = "./data/crecimiento.csv"

df = pd.read_csv(path, encoding="utf-8")

# %% [markdown]
# ## Clean data

# %%
# Being fair, this dataset was filtered in my web app so I donwload it directly from there.
# That's way it is already filtered to only tertiary activities and for June
df.head(10)
# Out:
#    Year  Financial and Insurance Activities  Real Estate Activities  \
# 0  2006                                3.70                    4.04
# 1  2007                               15.33                    3.80
# 2  2008                                6.89                    2.76
# 3  2009                                7.20                    3.79
# 4  2010                                4.45                    3.63
# 5  2011                                9.77                    2.73
# 6  2012                                9.46                    3.16
# 7  2013                                6.20                    3.28
# 8  2014                               14.53                    3.02
# 9  2015                                8.43                    3.08
#
#    Professional, Scientific, Technical and Administrative Support Activities  \
# 0                                               7.28
# 1                                               7.10
# ...

# %% [markdown]
# ## Plor

# %%
background = "#F4F1EA"
blue = "#4A90E2"
gray = "#D3D3D3"
x_axis = df["Year"]

fig, ax = plt.subplots(figsize=(9.8, 7.0), dpi=500)
fig.patch.set_facecolor(background)
ax.patch.set_facecolor(background)

for column in df.columns[1:]:
    plt.plot(
        x_axis,
        df[column],
        color=blue if column.startswith("Public") else gray,
        linewidth=2 if column.startswith("Public") else 1
    )

plt.axvspan(
    xmin=2020,
    xmax=2026,
    color=gray,
    alpha=0.2
)

plt.xticks(x_axis, rotation=45)

for side in ["top", "bottom", "left", "right"]:
    plt.gca().spines[side].set_visible(False)

for axis in ["y", "x"]:
    plt.tick_params(axis=axis, length=0)

plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{x:.0f}%"))

plt.ylabel("Growth", labelpad=10, fontsize=10, y=0.9)
plt.xlabel("Year", labelpad=10, fontsize=10)

plt.show()
